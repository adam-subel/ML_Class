# %%
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as colors

import numpy as np

import cartopy.crs as ccrs
import cartopy as cart
import cmocean
from matplotlib.animation import FuncAnimation
import numpy.fft as fft
import matplotlib.ticker as ticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from scipy.interpolate import interp2d
import graphviz
from gplearn.genetic import SymbolicRegressor
import gplearn as gp
from sklearn.utils.random import check_random_state
from mpl_toolkits.mplot3d import Axes3D

# %%
data = xr.open_zarr("/scratch/as15415/Data/Emulation_Data/Global_Ocean_1deg.zarr/")
data["T"][0].plot()

# %%
data = xr.open_zarr("/scratch/as15415/Data/Emulation_Data/Global_Ocean_1deg.zarr/")
data = data["T"]

# data_1 = data.sel(xu_ocean = slice(35,80))
# data_2 = data.sel(xu_ocean = slice(-280,-235))
# data_2["xu_ocean"] = data_2["xu_ocean"].data+360
# data = xr.concat([data_1,data_2],dim = "xu_ocean")
# data = data.sel(yu_ocean = slice(-40,30))

# Pacific


data = data.sel(xu_ocean = slice(-208,-80),yu_ocean = slice(-31,30))

wet =np.isnan(data[0])
wet = xr.where(wet==0,np.nan,0)    
wet = np.isnan(wet)
wet = np.nan_to_num(wet.to_numpy())
wet_bool = np.array(wet).astype(bool)

locs = np.argwhere(wet_bool)

Nx = data.xu_ocean.data.size
Ny = data.yu_ocean.data.size

# %%
clim = np.array(data.groupby('time.dayofyear').mean('time').compute())
clim = clim[:,wet_bool]
# clim = clim.mean(axis = [1,2])

# %%
def grid_vec(locs,to_plot):
    u = np.zeros((Ny,Nx))*np.nan

    u[locs[:,0],locs[:,1]] = to_plot.squeeze()
    return u

# %%
flattened = data[0:7305].to_numpy()[:,wet_bool]
# flattened = flattened/(flattened.mean())

# %%
for i in range(7305):
    day_yr = data.time.data[i].dayofyr-1
    flattened[i] = flattened[i] - clim[day_yr]

# %%
plt.plot(flattened.mean(axis=1))

# %%
U, S, V = np.linalg.svd(flattened, full_matrices=False)

# %%
plt.rc('axes', labelsize=18)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=18)    # fontsize of the tick labels
plt.rc('ytick', labelsize=18)    # fontsize of the tick labels
plt.rc('figure', titlesize=18)

fig, axs = plt.subplots(1, 1, figsize=(12,6),
                        gridspec_kw={'width_ratios': [1], 'height_ratios': [1], 'wspace': 0.25,'hspace':.5},
                       )
plot_1 = axs.pcolor(data.xu_ocean,data.yu_ocean,grid_vec(locs,V[0,:]),cmap = cmocean.cm.diff,norm = colors.CenteredNorm())

# axs.add_feature(cart.feature.LAND, zorder=100, edgecolor='k')
# gl = axs.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
#                   linewidth=2, color='gray', alpha=0.5, linestyle='--')
# gl.top_labels = False
# gl.right_labels = False
# gl.yrotation = False
# gl.xformatter = LONGITUDE_FORMATTER
# gl.yformatter = LATITUDE_FORMATTER
axs.set_title(r"CM2.6",size = 15)
plt.colorbar(plot_1,aspect=12,shrink=.9)
plt.title("PC1",fontsize=20)
# Out:
# /state/partition1/job-44913917/ipykernel_2299551/1673697905.py:9: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plot_1 = axs.pcolor(data.xu_ocean,data.yu_ocean,grid_vec(locs,V[0,:]),cmap = cmocean.cm.diff,norm = colors.CenteredNorm())
# Text(0.5, 1.0, 'PC1')

# %%
plt.rc('axes', labelsize=18)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=18)    # fontsize of the tick labels
plt.rc('ytick', labelsize=18)    # fontsize of the tick labels
plt.rc('figure', titlesize=18)

fig, axs = plt.subplots(1, 1, figsize=(12,6),
                        gridspec_kw={'width_ratios': [1], 'height_ratios': [1], 'wspace': 0.25,'hspace':.5},
                       )
plot_1 = axs.pcolor(data.xu_ocean,data.yu_ocean,grid_vec(locs,V[1,:]),cmap = cmocean.cm.diff,norm = colors.CenteredNorm())

# axs.add_feature(cart.feature.LAND, zorder=100, edgecolor='k')
# gl = axs.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
#                   linewidth=2, color='gray', alpha=0.5, linestyle='--')
# gl.top_labels = False
# gl.right_labels = False
# gl.yrotation = False
# gl.xformatter = LONGITUDE_FORMATTER
# gl.yformatter = LATITUDE_FORMATTER
axs.set_title(r"CM2.6",size = 15)
plt.colorbar(plot_1,aspect=12,shrink=.9)
plt.title("PC2",fontsize=20)
# Out:
# /state/partition1/job-44913917/ipykernel_2299551/4283794907.py:9: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plot_1 = axs.pcolor(data.xu_ocean,data.yu_ocean,grid_vec(locs,V[1,:]),cmap = cmocean.cm.diff,norm = colors.CenteredNorm())
# Text(0.5, 1.0, 'PC2')

# %%
plt.rc('axes', labelsize=18)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=18)    # fontsize of the tick labels
plt.rc('ytick', labelsize=18)    # fontsize of the tick labels
plt.rc('figure', titlesize=18)

fig, axs = plt.subplots(1, 1, figsize=(12,6),
                        gridspec_kw={'width_ratios': [1], 'height_ratios': [1], 'wspace': 0.25,'hspace':.5},
                       )
plot_1 = axs.pcolor(data.xu_ocean,data.yu_ocean,grid_vec(locs,V[2,:]),cmap = cmocean.cm.diff,norm = colors.CenteredNorm())

# axs.add_feature(cart.feature.LAND, zorder=100, edgecolor='k')
# gl = axs.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
#                   linewidth=2, color='gray', alpha=0.5, linestyle='--')
# gl.top_labels = False
# gl.right_labels = False
# gl.yrotation = False
# gl.xformatter = LONGITUDE_FORMATTER
# gl.yformatter = LATITUDE_FORMATTER
axs.set_title(r"CM2.6",size = 15)
plt.colorbar(plot_1,aspect=12,shrink=.9)
plt.title("PC3",fontsize=20)
# Out:
# /state/partition1/job-44913917/ipykernel_2299551/2646049565.py:9: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plot_1 = axs.pcolor(data.xu_ocean,data.yu_ocean,grid_vec(locs,V[2,:]),cmap = cmocean.cm.diff,norm = colors.CenteredNorm())
# Text(0.5, 1.0, 'PC3')

# %%
plt.plot(U[:,1],"k",label = "PC 2")
plt.plot(U[:,2],"r",label = "PC 3")
plt.plot(U[:,0],"b",label = "PC 1")

plt.legend()
# plt.plot(U[:,3])

# %%
plt.plot(U[:,0],"b",label = "PC 1")
plt.legend()

# %%
plt.plot(S[:20])
plt.ylabel(r"$\sigma$")
# Out:
# Text(0, 0.5, '$\\sigma$')

# %%
PC1 = np.expand_dims(U[:,0],-1)
PC1 = (PC1- PC1.mean())/PC1.std()
PC2 = np.expand_dims(U[:,1],-1)
PC2 = (PC2- PC2.mean())/PC2.std()
PC3 = np.expand_dims(U[:,2],-1)
PC3 = (PC3- PC3.mean())/PC3.std()

inpts = np.hstack((PC2,PC3))
inpts_2 = np.hstack((PC1,PC3))

# %%
est_gp = SymbolicRegressor(population_size=1000,
                           generations=20, stopping_criteria=0.001,
                           p_crossover=0.7, p_subtree_mutation=0.1,
                           p_hoist_mutation=0.05, p_point_mutation=0.1, feature_names= ['PC1',],
                           max_samples=0.9, verbose=1,function_set= (['add','mul']),
                           parsimony_coefficient=0.001, random_state=0,const_range=(-20,20),
                          metric="mse")
est_gp.fit(PC1, PC2.squeeze())
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    48.57       4.4629e+22        7          1.00413         0.988772     24.13s
#    1     8.54           1560.2        7         0.997913          1.01946     13.61s
#    2     4.35      8.14198e+09        7         0.996147          1.04736     12.11s
#    3     3.85      1.45931e+06        7         0.993571          1.05691     11.39s
#    4     6.00          28.4679        7         0.993192          1.06011     10.98s
#    5     5.89           153359        7         0.990128          1.08558     10.16s
#    6     4.68      5.18324e+08        7         0.992498          1.06594      9.36s
#    7     2.67          23.5899        7         0.992742           1.0639      8.42s
#    8     2.29       1.3274e+09        3          0.98865          1.09825      7.73s
#    9     2.30          5862.07        5         0.991154           1.0763      6.97s
#   10     3.04      6.40944e+06        3          0.99076          1.07984      6.44s
#   11     3.02      6.15042e+09        3          0.99032          1.08348      5.66s
#   12     3.29          1588.62        3         0.990375          1.08302      4.97s
#   13     3.28          2169.86        3         0.991544          1.07336      4.28s
#   14     3.30          2710.76        3         0.991924           1.0702      3.58s
#   15     3.56          5948.64        3         0.989927           1.0867      2.86s
#   16     3.44          28244.9        3         0.990236          1.08416      2.16s
#   17     3.20          4083.49        3         0.991344          1.07502      1.42s
#   18     3.44      1.11761e+13        3         0.991096          1.07707      0.71s
#   19     3.37      9.88928e+10        3         0.991939          1.07007      0.00s
# SymbolicRegressor(const_range=(-20, 20), feature_names=['PC1'],
#                   function_set=['add', 'mul'], max_samples=0.9, metric='rmse',
#                   p_crossover=0.7, p_hoist_mutation=0.05, p_point_mutation=0.1,
#                   p_subtree_mutation=0.1, random_state=0,
#                   stopping_criteria=0.001, verbose=1)

# %%
dot_data = est_gp._program.export_graphviz()
graph = graphviz.Source(dot_data) 
graph.render('images/ex1_child', format='png', cleanup=True)
graph

# %%
A = np.hstack((np.ones_like(PC1),PC1,PC1**2,PC1**3,PC1**4))
c = np.linalg.lstsq(A,PC2)
c = c[0]
lin_reg_fit = np.matmul(A,c)
print(c)
# Out:
# [[-0.06152816]
#  [-0.18137603]
#  [ 0.13054029]
#  [ 0.0530516 ]
#  [-0.01348315]]
# /state/partition1/job-44913917/ipykernel_2299551/3430406005.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   c = np.linalg.lstsq(A,PC2)

# %%
plt.plot(PC2,"k",label = "PC 2")
plt.plot(est_gp.predict(PC1),"r",label = "Symbolic Regression")
plt.plot(lin_reg_fit,"b",label = "Linear Regression")
plt.legend()

# %%
est_gp = SymbolicRegressor(population_size=750,
                           generations=4, stopping_criteria=0.0001,
                           p_crossover=0.7, p_subtree_mutation=0.1,
                           p_hoist_mutation=0.05, p_point_mutation=0.1, feature_names= ['PC2','PC3'],
                           max_samples=0.9, verbose=1,function_set= (['add','mul']),
                           parsimony_coefficient=0.01, random_state=0,const_range=(-10,10))
est_gp.fit(inpts, PC1)
# Out:
# /ext3/miniconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    34.29       2.1679e+14        7         0.764358         0.762342      2.41s
#    1     7.56          3.78047        7         0.757654          0.74342      1.10s
#    2     5.55          6.82725        9         0.752132         0.737449      0.53s
#    3     5.09          3.00243        7         0.752325         0.791348      0.00s
# SymbolicRegressor(const_range=(-10, 10), feature_names=['PC2', 'PC3'],
#                   function_set=['add', 'mul'], generations=4, max_samples=0.9,
#                   p_crossover=0.7, p_hoist_mutation=0.05, p_point_mutation=0.1,
#                   p_subtree_mutation=0.1, parsimony_coefficient=0.01,
#                   population_size=750, random_state=0, stopping_criteria=0.0001,
#                   verbose=1)

# %%
dot_data = est_gp._program.export_graphviz()
graph = graphviz.Source(dot_data) 
graph.render('images/ex1_child', format='png', cleanup=True)
graph

# %%
A = np.hstack((np.ones_like(PC3),PC3,PC3**2,PC3**3,PC3**4,
               PC2,PC2**2,PC2**3,PC2**4,
              PC2*PC3,PC2**2*PC3,PC2*PC3**2,PC2**2*PC3**2))
c = np.linalg.lstsq(A,PC1)
c = c[0]
lin_reg_fit = np.matmul(A,c)
print(c)
# Out:
# [[ 0.25252908]
#  [-0.13074354]
#  [-0.49054016]
#  [ 0.04100037]
#  [ 0.07361241]
#  [-0.07354343]
#  [-0.03911808]
#  [-0.00867802]
#  [ 0.00296165]
#  [ 0.27981561]
#  [ 0.08793808]
#  [ 0.13222646]
#  [ 0.11435093]]
# /state/partition1/job-44913917/ipykernel_2299551/3334084556.py:4: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   c = np.linalg.lstsq(A,PC1)

# %%
plt.plot(PC2,"k",label = "PC 2")
plt.plot(est_gp.predict(inpts),"r",label = "Symbolic Regression")
plt.plot(lin_reg_fit,"b",label = "Linear Regression")
plt.legend()

# %%
est_gp = SymbolicRegressor(population_size=750,
                           generations=10, stopping_criteria=0.0001,
                           p_crossover=0.7, p_subtree_mutation=0.1,
                           p_hoist_mutation=0.05, p_point_mutation=0.1, feature_names= ['PC1','PC3'],
                           max_samples=0.9, verbose=1,function_set= (['add','mul']),
                           parsimony_coefficient=0.01, random_state=0,const_range=(-10,10),
                          metric = "mse")
est_gp.fit(inpts_2, PC2)
# Out:
# /ext3/miniconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    34.29      9.68853e+33        7         0.935481          0.85928      7.29s
#    1     7.54          982.638        7         0.923687         0.965345      4.45s
#    2     6.78          40713.1        9          0.90703         0.956897      3.83s
#    3     6.06             6996        9         0.909501          0.93467      3.27s
#    4     6.32          2008.29        7         0.901266         0.991697      2.73s
#    5     6.16          84.9797        7         0.902752         0.978329      2.17s
#    6     6.05      1.13874e+06        7         0.898959          1.01244      1.63s
#    7     6.65      1.01433e+13        7         0.899012          1.01196      1.11s
#    8     7.34      1.09827e+06        7         0.894026          1.05681      0.57s
#    9     7.16           878764        7         0.896097          1.03818      0.00s
# SymbolicRegressor(const_range=(-10, 10), feature_names=['PC1', 'PC3'],
#                   function_set=['add', 'mul'], generations=10, max_samples=0.9,
#                   metric='mse', p_crossover=0.7, p_hoist_mutation=0.05,
#                   p_point_mutation=0.1, p_subtree_mutation=0.1,
#                   parsimony_coefficient=0.01, population_size=750,
#                   random_state=0, stopping_criteria=0.0001, verbose=1)

# %%
dot_data = est_gp._program.export_graphviz()
graph = graphviz.Source(dot_data) 
graph.render('images/ex1_child', format='png', cleanup=True)
graph

# %%
A = np.hstack((np.ones_like(PC3),PC3,PC3**2,PC3**3,PC3**4,
               PC1,PC1**2,PC1**3,PC1**4,
              PC1*PC3,PC1**2*PC3,PC1*PC3**2,PC1**2*PC3**2))
c = np.linalg.lstsq(A,PC2)
c = c[0]
lin_reg_fit = np.matmul(A,c)
print(c)
# Out:
# [[-0.0173889 ]
#  [ 0.07230037]
#  [-0.02634974]
#  [-0.05509467]
#  [-0.02264229]
#  [-0.49929671]
#  [ 0.07153186]
#  [ 0.15154283]
#  [ 0.01687537]
#  [ 0.51811983]
#  [ 0.22331088]
#  [ 0.14907764]
#  [ 0.04440441]]
# /state/partition1/job-44913917/ipykernel_2299551/4052644001.py:4: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   c = np.linalg.lstsq(A,PC2)

# %%
plt.plot(PC2,"k",label = "PC 2")
plt.plot(est_gp.predict(inpts),"r",label = "Symbolic Regression")
plt.plot(lin_reg_fit,"b",label = "Linear Regression")
plt.legend()
